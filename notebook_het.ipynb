# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sin,cos,tan

# %%
data_df = pd.read_csv('14141Kdata-Copy.csv', header=None)

# %%
data = data_df.values

# %%
plt.plot(data[0:461,0],data[0:461,1],data[0:461,0],data[0:461,2],data[0:461,0],data[0:461,3],data[0:461,0],data[0:461,4])
# Out:
# [<matplotlib.lines.Line2D at 0x224ff03a588>,
#  <matplotlib.lines.Line2D at 0x224ff03a7f0>,
#  <matplotlib.lines.Line2D at 0x224ff03af60>,
#  <matplotlib.lines.Line2D at 0x224ff049400>]

# %%
#incidence angle
i = 30
#emergence angle
e = 0
#phase angle
g = 30

mu = cos(i)
mu_0 = cos(e)

# %%
def get_B(h,g):
    
    B = 1/(1 + (1/h)*tan(g/2))
    return B

def get_P(g,b,c):
    
    P = 1 + b*cos(g) + c*((3/2)*cos(g)*cos(g) - (1/2))
    return P
# Out:
# 0.5662294775364266
